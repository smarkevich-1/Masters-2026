# %%
from masters_fetch import fetch_and_push
fetch_and_push()
# Out:
# ...
# ⛳ Fetching Masters scores... (06:21:14)
#   ✅ 91 players fetched · Round 1
#   💾 Saved → C:\Users\stuma\Documents\Python\Masters-2026\scores.json
#
# 🏆 Top 5:
#   T1     Haotong Li                       E
#   T1     Max Homa                         E
#   T1     Naoyuki Kataoka                  E
#   T4     Johnny Keefer                    E
#   T4     Carlos Ortiz                     E
#   📤 Pushing to GitHub...
#   ❌ Git push failed: remote: Repository not found.
# fatal: repository 'https://github.com/smarkevich-1/C:\Users\stuma\Documents\Python\Masters-2026.git/' not found
#      Double-check GITHUB_USERNAME, GITHUB_TOKEN, and REPO_PATH in the config section.
#
# 🕐 2026-04-09T06:21:15.370709
# ...
# {'tournament': '2026 Masters Tournament',
#  'lastUpdated': '2026-04-09T06:21:15.370709',
#  'round': 1,
#  'status': 'STATUS_IN_PROGRESS',
#  'players': [{'name': 'Haotong Li',
#    'pos': 'T1',
#    'sortOrder': 1,
#    'scoreToPar': 0,
#    'scoreDisplay': 'E',
#    'r1': None,
# ...

# %%
from masters_fetch import fetch_and_push
fetch_and_push()
# Out:
# ...
# ⛳ Fetching Masters scores... (09:15:13)
#   ✅ 91 players fetched · Round 1
#   💾 Saved → C:\Users\stuma\Documents\Python\Masters-2026\scores.json
#
# 🏆 Top 5:
#   T1     Tommy Fleetwood                  E
#   T1     Patrick Reed                     E
#   T3     José María Olazábal              E
#   T3     Kurt Kitayama                    E
#   T3     Akshay Bhatia                    E
#   📤 Pushing to GitHub...
